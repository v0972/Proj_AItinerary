# %%
import pandas as pd
df = pd.read_csv("E:/專題/景點爬蟲/tripadvisor/tripadvisor/情感分析/tripadvisor/Tokyo Metropolitan Government Buildings Observatories",encoding="utf-8")
df
# Out:
#                                                       評論  \
# 0                               ['透過行動裝置', '有趣的地方，值得一看']
# 1      ['餐廳和小攤上的壽司都很新鮮', '儘管金槍魚拍賣和幾家出名的壽司店都離開築地，搬到豐州去...
# 2                             ['透過行動裝置', '體驗很好，不過也是個景點']
# 3                          ['透過行動裝置', '大部分地方在1月1日至4日關閉']
# 4                                     ['透過行動裝置', '令人驚奇']
# ...                                                  ...
# 10097  ['一個星期后,在這座城市，我就知道這是很大的。 。 。但我並沒有真正的嚴重程度，直到我實際...
# 10098  ['免費欣賞東京的天際線', '我們還去了 45 樓的觀景層能看到東京的夜景。 從那裡我們排...
# 10099  ['這是一個免費的建築物來讓你進入，拿到很棒的能看到東京的美麗景色。 值得遊覽的一天一夜。'...
# 10100                             ['透過行動裝置', '風景很好&免費的']
# 10101  ['很棒的東京的景色，而且它是免費的', '我覺得很多人犯錯，相信天文台都安置在這棟建築靠近...
#
#                              評論星等
# 0      ui_bubble_rating bubble_40
# 1      ui_bubble_rating bubble_40
# 2      ui_bubble_rating bubble_30
# 3      ui_bubble_rating bubble_30
# 4      ui_bubble_rating bubble_50
# ...                           ...
# 10097  ui_bubble_rating bubble_50
# 10098  ui_bubble_rating bubble_40
# 10099  ui_bubble_rating bubble_50
# 10100  ui_bubble_rating bubble_50
# 10101  ui_bubble_rating bubble_40
#
# [10102 rows x 2 columns]

# %%
content = df["評論"] 

import re
def del_word(x):
    s = (x.replace("透過行動裝置","").replace("[","").replace("]","").replace(",","").replace("...更多","")
          .replace("'","").strip()).replace(' 由 Asia Online Language Studio 翻譯 評等翻譯',"").replace("TripAdvisor 會員","")

    result = re.split('體驗日期\W\s\d+年\d+月',s)
    result2 = re.split('感謝\s+\w+', "".join(result)) 
    
    return result2

comment = []
for i in content:
    b = del_word(''.join(i))
    comment.append(b)

# %%
df["comment"] = comment 
df = df.drop(columns=["評論"])

star = df["評論星等"] 
stars = []
for i in star:
    a = i.replace("ui_bubble_rating bubble_", "")
    stars.append(a)

df["Star"] = stars
df = df.drop(columns=["評論星等"])

# %%
pos=''
neg=''
for i in range(df.shape[0]):
    if df.loc[i,"Star"] in ["40","50"]:
        pos+=(df.loc[i,'comment'][0]+'\n')
    else:
        neg+=(df.loc[i,'comment'][0]+'\n')

# %%
with open('C:\\Users\\Big data\\AppData\\Local\\Programs\\Python\\Python37\\Lib\\site-packages\\snownlp\\sentiment\\pos_test.txt',
          "w", encoding = 'utf-8') as f:
    f.write(pos)
